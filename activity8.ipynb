# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('datasets\\Chicago_Crimes.csv')

# %%
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')  # convert to datetime
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month

# %% [markdown]
# <h1>FILTERING</h1>

# %%
filter1 =df[df['Primary Type']== 'ASSAULT']
filter2 = filter1[filter1['Arrest'] == True]
filter3 = filter2[filter2['Year'] == 2025]
filter4 = filter3[filter3['Location Description'] == 'STREET']

# %%
A_Assault = filter4.groupby(['Longitude', 'Latitude']).size().reset_index(name= 'Arrested Assault')

# %%
import folium
from folium.plugins import HeatMap

Robbery_Data = df[(df['Primary Type'] == 'ROBBERY') & 
                  (df['Arrest'] == True) & 
                  (df['Year'] == 2025) & 
                  (df['Location Description'] == 'STREET')]

Robbery_Data['Robbery Count'] = 1

heat_df = Robbery_Data[['Latitude', 'Longitude', 'Robbery Count']].dropna().values.tolist()

map_ = folium.Map(location=[41.8781, -87.6298], zoom_start=11)  # Centered on Chicago
HeatMap(heat_df).add_to(map_)
map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a1cc8cd60f5d7f751f052a64fabbf543 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a1cc8cd60f5d7f751f052a64fabbf543&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a1cc8cd60f5d7f751f052a64fabbf543 = L.map(
#                 &quot;map_a1cc8cd60f5d7f751f052a64fabbf543&quot;,
#                 {
#                     center: [41.8781, -87.6298],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_32e273d17f89ee8a37f4028127e702c1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_32e273d17f89ee8a37f4028127e702c1.addTo(map_a1cc8cd60f5d7f751f052a64fabbf543);
#
#
#             var heat_map_6498c5149d27be95cdec1bb5243bf238 = L.heatLayer(
#                 [[41.748799881, -87.613650624, 1.0], [42.018498254, -87.672983233, 1.0], [41.799051183, -87.790549789, 1.0], [41.88574159, -87.631803553, 1.0], [41.938118544, -87.65241855, 1.0], [41.934710938, -87.653928561, 1.0], [41.722366012, -87.657840504, 1.0], [41.75835215, -87.582250988, 1.0], [41.874756234, -87.762565879, 1.0], [41.771291879, -87.663995669, 1.0], [41.806035591, -87.657607865, 1.0], [41.721623049, -87.624701342, 1.0], [41.812659585, -87.742076464, 1.0], [41.795498956, -87.676780956, 1.0], [41.776262757, -87.604618223, 1.0], [41.802875687, -87.607907402, 1.0], [41.975678397, -87.772106296, 1.0], [41.862461922, -87.709778547, 1.0], [41.8744162, -87.638591667, 1.0], [41.880075633, -87.73790816, 1.0], [41.80716827, -87.743142974, 1.0], [41.773305592, -87.685919366, 1.0], [41.889488842, -87.627994441, 1.0], [41.769466772, -87.657874472, 1.0], [41.767723253, -87.661466794, 1.0]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_6498c5149d27be95cdec1bb5243bf238.addTo(map_a1cc8cd60f5d7f751f052a64fabbf543);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <h1>INSIGHT1</h1>

# %% [markdown]
# <H4>South Side Concentration</H4>
# <h4>Assault incidents with arrests are heavily concentrated on the South Side, particularly around Washington Park, Englewood, and Greater Grand Crossing.</h4>

# %%
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_707a8d6af8d523ddf657124fe1549939 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_707a8d6af8d523ddf657124fe1549939&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_707a8d6af8d523ddf657124fe1549939 = L.map(
#                 &quot;map_707a8d6af8d523ddf657124fe1549939&quot;,
#                 {
#                     center: [41.8781, -87.6298],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c20930a545638ced7b28c854b4ac3e78 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c20930a545638ced7b28c854b4ac3e78.addTo(map_707a8d6af8d523ddf657124fe1549939);
#
#
#             var heat_map_a129ad2c510f0429ca922ee88bb27a7d = L.heatLayer(
#                 [[41.909224529, -87.777791622, 1.0], [41.895995456, -87.772334331, 1.0], [41.893094286, -87.772231169, 1.0], [41.881183818, -87.76157228, 1.0], [41.909981092, -87.752659874, 1.0], [41.975292995, -87.750926925, 1.0], [41.875483068, -87.745085159, 1.0], [41.937749035, -87.740665125, 1.0], [41.935752015, -87.738162368, 1.0], [41.878743645, -87.736124908, 1.0], [41.883784731, -87.735578531, 1.0], [41.912465307, -87.732522476, 1.0], [41.854713363, -87.724844718, 1.0], [41.870735748, -87.724075964, 1.0], [41.866260112, -87.718457311, 1.0], [41.91134731, -87.717808027, 1.0], [41.959976534, -87.715553381, 1.0], [41.858303435, -87.715189395, 1.0], [41.841905622, -87.713504951, 1.0], [41.912997042, -87.711777872, 1.0], [41.872497397, -87.710742126, 1.0], [41.858568011, -87.710319284, 1.0], [41.840806317, -87.709155782, 1.0], [41.839955532, -87.706121788, 1.0], [41.783955089, -87.704493576, 1.0], [41.778962112, -87.703790763, 1.0], [41.795835835, -87.703621991, 1.0], [41.990447044, -87.698746362, 1.0], [41.776766148, -87.698210298, 1.0], [41.875902562, -87.69615018, 1.0], [41.910227448, -87.6961359, 1.0], [41.763935202, -87.690566076, 1.0], [41.822893602, -87.689118243, 1.0], [41.902999018, -87.688739745, 1.0], [41.934089387, -87.687941658, 1.0], [41.873882904, -87.686840358, 1.0], [41.838509873, -87.686433211, 1.0], [41.789485613, -87.683915798, 1.0], [42.015451197, -87.680481208, 1.0], [42.009269306, -87.675326876, 1.0], [42.00167049, -87.673863642, 1.0], [41.812222809, -87.666808738, 1.0], [41.694399654, -87.666481439, 1.0], [41.813312219, -87.666324236, 1.0], [42.019844934, -87.666216277, 1.0], [41.857112307, -87.666126249, 1.0], [41.794035506, -87.663814097, 1.0], [41.75322329, -87.663505427, 1.0], [41.857190995, -87.661735179, 1.0], [41.76312381, -87.661467128, 1.0], [41.869387636, -87.658659333, 1.0], [41.788449223, -87.658371945, 1.0], [41.860008714, -87.656485619, 1.0], [41.714978435, -87.655998622, 1.0], [41.978211897, -87.655746547, 1.0], [41.975559264, -87.654987667, 1.0], [41.802850483, -87.652664297, 1.0], [41.802477219, -87.652657244, 1.0], [41.766401059, -87.648086494, 1.0], [41.858281851, -87.646654964, 1.0], [41.750185415, -87.644029945, 1.0], [41.827159155, -87.641619819, 1.0], [41.926227907, -87.639139581, 1.0], [41.685119668, -87.638907587, 1.0], [41.780409069, -87.635057334, 1.0], [41.892383161, -87.634588313, 1.0], [41.879393185, -87.632992969, 1.0], [41.903129838, -87.631929153, 1.0], [41.903478069, -87.631433102, 1.0], [41.897021755, -87.629781141, 1.0], [41.699805673, -87.628716247, 1.0], [41.880251406, -87.626157171, 1.0], [41.885729338, -87.625780935, 1.0], [41.857196267, -87.625596317, 1.0], [41.880404956, -87.624356147, 1.0], [41.76508964, -87.623288534, 1.0], [41.772831904, -87.622942868, 1.0], [41.682581566, -87.617504356, 1.0], [41.783412793, -87.615701951, 1.0], [41.777950825, -87.615568537, 1.0], [41.807580274, -87.61547631, 1.0], [41.805124173, -87.615041585, 1.0], [41.7766178, -87.614802505, 1.0], [41.751164599, -87.612198632, 1.0], [41.69187607, -87.611711564, 1.0], [41.774327797, -87.610663438, 1.0], [41.696888796, -87.608909298, 1.0], [41.824058215, -87.606523648, 1.0], [41.74181305, -87.604967558, 1.0], [41.730949275, -87.604683641, 1.0], [41.800196824, -87.603936354, 1.0], [41.732105874, -87.603582467, 1.0], [41.750328686, -87.601521784, 1.0], [41.717810825, -87.595858138, 1.0], [41.803056534, -87.586453094, 1.0], [41.769261197, -87.584425842, 1.0], [41.74938132, -87.572285187, 1.0], [41.711241451, -87.56576559, 1.0], [41.709903512, -87.563906369, 1.0], [41.759040861, -87.562348408, 1.0], [41.733068435, -87.55133095, 1.0], [41.746053316, -87.549146964, 1.0], [41.654974814, -87.547146046, 1.0]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_a129ad2c

# %% [markdown]
# <H1>FILTERING</H1>

# %%
filter1 = df[df['Primary Type'] == 'ASSAULT']
filter2 = filter1[filter1['Arrest'] == True]
filter3 = filter2[filter2['Year'] == 2025]
filter4 = filter3[filter3['Location Description'] == 'STREET']

import folium
from folium.plugins import HeatMap

A_Assault = filter4.groupby(['Longitude', 'Latitude']) \
                  .size() \
                  .reset_index(name='Arrested Assault')

heat_df = A_Assault[['Latitude', 'Longitude', 'Arrested Assault']].dropna().values.tolist()
map_ = folium.Map(location=[41.8781, -87.6298], zoom_start=11)
HeatMap(heat_df).add_to(map_)
map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_51416256ef399b45f51b782157106137 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_51416256ef399b45f51b782157106137&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_51416256ef399b45f51b782157106137 = L.map(
#                 &quot;map_51416256ef399b45f51b782157106137&quot;,
#                 {
#                     center: [41.8781, -87.6298],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_78b3a7f380c6d2137241432a4fa9add0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_78b3a7f380c6d2137241432a4fa9add0.addTo(map_51416256ef399b45f51b782157106137);
#
#
#             var heat_map_bdde8d3aa4f323a2146f7ff1d3e16ca1 = L.heatLayer(
#                 [[41.909224529, -87.777791622, 1.0], [41.895995456, -87.772334331, 1.0], [41.893094286, -87.772231169, 1.0], [41.881183818, -87.76157228, 1.0], [41.909981092, -87.752659874, 1.0], [41.975292995, -87.750926925, 1.0], [41.875483068, -87.745085159, 1.0], [41.937749035, -87.740665125, 1.0], [41.935752015, -87.738162368, 1.0], [41.878743645, -87.736124908, 1.0], [41.883784731, -87.735578531, 1.0], [41.912465307, -87.732522476, 1.0], [41.854713363, -87.724844718, 1.0], [41.870735748, -87.724075964, 1.0], [41.866260112, -87.718457311, 1.0], [41.91134731, -87.717808027, 1.0], [41.959976534, -87.715553381, 1.0], [41.858303435, -87.715189395, 1.0], [41.841905622, -87.713504951, 1.0], [41.912997042, -87.711777872, 1.0], [41.872497397, -87.710742126, 1.0], [41.858568011, -87.710319284, 1.0], [41.840806317, -87.709155782, 1.0], [41.839955532, -87.706121788, 1.0], [41.783955089, -87.704493576, 1.0], [41.778962112, -87.703790763, 1.0], [41.795835835, -87.703621991, 1.0], [41.990447044, -87.698746362, 1.0], [41.776766148, -87.698210298, 1.0], [41.875902562, -87.69615018, 1.0], [41.910227448, -87.6961359, 1.0], [41.763935202, -87.690566076, 1.0], [41.822893602, -87.689118243, 1.0], [41.902999018, -87.688739745, 1.0], [41.934089387, -87.687941658, 1.0], [41.873882904, -87.686840358, 1.0], [41.838509873, -87.686433211, 1.0], [41.789485613, -87.683915798, 1.0], [42.015451197, -87.680481208, 1.0], [42.009269306, -87.675326876, 1.0], [42.00167049, -87.673863642, 1.0], [41.812222809, -87.666808738, 1.0], [41.694399654, -87.666481439, 1.0], [41.813312219, -87.666324236, 1.0], [42.019844934, -87.666216277, 1.0], [41.857112307, -87.666126249, 1.0], [41.794035506, -87.663814097, 1.0], [41.75322329, -87.663505427, 1.0], [41.857190995, -87.661735179, 1.0], [41.76312381, -87.661467128, 1.0], [41.869387636, -87.658659333, 1.0], [41.788449223, -87.658371945, 1.0], [41.860008714, -87.656485619, 1.0], [41.714978435, -87.655998622, 1.0], [41.978211897, -87.655746547, 1.0], [41.975559264, -87.654987667, 1.0], [41.802850483, -87.652664297, 1.0], [41.802477219, -87.652657244, 1.0], [41.766401059, -87.648086494, 1.0], [41.858281851, -87.646654964, 1.0], [41.750185415, -87.644029945, 1.0], [41.827159155, -87.641619819, 1.0], [41.926227907, -87.639139581, 1.0], [41.685119668, -87.638907587, 1.0], [41.780409069, -87.635057334, 1.0], [41.892383161, -87.634588313, 1.0], [41.879393185, -87.632992969, 1.0], [41.903129838, -87.631929153, 1.0], [41.903478069, -87.631433102, 1.0], [41.897021755, -87.629781141, 1.0], [41.699805673, -87.628716247, 1.0], [41.880251406, -87.626157171, 1.0], [41.885729338, -87.625780935, 1.0], [41.857196267, -87.625596317, 1.0], [41.880404956, -87.624356147, 1.0], [41.76508964, -87.623288534, 1.0], [41.772831904, -87.622942868, 1.0], [41.682581566, -87.617504356, 1.0], [41.783412793, -87.615701951, 1.0], [41.777950825, -87.615568537, 1.0], [41.807580274, -87.61547631, 1.0], [41.805124173, -87.615041585, 1.0], [41.7766178, -87.614802505, 1.0], [41.751164599, -87.612198632, 1.0], [41.69187607, -87.611711564, 1.0], [41.774327797, -87.610663438, 1.0], [41.696888796, -87.608909298, 1.0], [41.824058215, -87.606523648, 1.0], [41.74181305, -87.604967558, 1.0], [41.730949275, -87.604683641, 1.0], [41.800196824, -87.603936354, 1.0], [41.732105874, -87.603582467, 1.0], [41.750328686, -87.601521784, 1.0], [41.717810825, -87.595858138, 1.0], [41.803056534, -87.586453094, 1.0], [41.769261197, -87.584425842, 1.0], [41.74938132, -87.572285187, 1.0], [41.711241451, -87.56576559, 1.0], [41.709903512, -87.563906369, 1.0], [41.759040861, -87.562348408, 1.0], [41.733068435, -87.55133095, 1.0], [41.746053316, -87.549146964, 1.0], [41.654974814, -87.547146046, 1.0]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_bdde8d3a

# %% [markdown]
# <H1>INSIGHT2</H1>

# %% [markdown]
# <h4>Street-Level Hotspots</h4>
# <h4>Since we filtered for Location Description == 'STREET', the map shows assaults occurring in public and exposed areas, indicating potential for witness reports and police response.
# </h4>

# %%
map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_51416256ef399b45f51b782157106137 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_51416256ef399b45f51b782157106137&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_51416256ef399b45f51b782157106137 = L.map(
#                 &quot;map_51416256ef399b45f51b782157106137&quot;,
#                 {
#                     center: [41.8781, -87.6298],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_78b3a7f380c6d2137241432a4fa9add0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_78b3a7f380c6d2137241432a4fa9add0.addTo(map_51416256ef399b45f51b782157106137);
#
#
#             var heat_map_bdde8d3aa4f323a2146f7ff1d3e16ca1 = L.heatLayer(
#                 [[41.909224529, -87.777791622, 1.0], [41.895995456, -87.772334331, 1.0], [41.893094286, -87.772231169, 1.0], [41.881183818, -87.76157228, 1.0], [41.909981092, -87.752659874, 1.0], [41.975292995, -87.750926925, 1.0], [41.875483068, -87.745085159, 1.0], [41.937749035, -87.740665125, 1.0], [41.935752015, -87.738162368, 1.0], [41.878743645, -87.736124908, 1.0], [41.883784731, -87.735578531, 1.0], [41.912465307, -87.732522476, 1.0], [41.854713363, -87.724844718, 1.0], [41.870735748, -87.724075964, 1.0], [41.866260112, -87.718457311, 1.0], [41.91134731, -87.717808027, 1.0], [41.959976534, -87.715553381, 1.0], [41.858303435, -87.715189395, 1.0], [41.841905622, -87.713504951, 1.0], [41.912997042, -87.711777872, 1.0], [41.872497397, -87.710742126, 1.0], [41.858568011, -87.710319284, 1.0], [41.840806317, -87.709155782, 1.0], [41.839955532, -87.706121788, 1.0], [41.783955089, -87.704493576, 1.0], [41.778962112, -87.703790763, 1.0], [41.795835835, -87.703621991, 1.0], [41.990447044, -87.698746362, 1.0], [41.776766148, -87.698210298, 1.0], [41.875902562, -87.69615018, 1.0], [41.910227448, -87.6961359, 1.0], [41.763935202, -87.690566076, 1.0], [41.822893602, -87.689118243, 1.0], [41.902999018, -87.688739745, 1.0], [41.934089387, -87.687941658, 1.0], [41.873882904, -87.686840358, 1.0], [41.838509873, -87.686433211, 1.0], [41.789485613, -87.683915798, 1.0], [42.015451197, -87.680481208, 1.0], [42.009269306, -87.675326876, 1.0], [42.00167049, -87.673863642, 1.0], [41.812222809, -87.666808738, 1.0], [41.694399654, -87.666481439, 1.0], [41.813312219, -87.666324236, 1.0], [42.019844934, -87.666216277, 1.0], [41.857112307, -87.666126249, 1.0], [41.794035506, -87.663814097, 1.0], [41.75322329, -87.663505427, 1.0], [41.857190995, -87.661735179, 1.0], [41.76312381, -87.661467128, 1.0], [41.869387636, -87.658659333, 1.0], [41.788449223, -87.658371945, 1.0], [41.860008714, -87.656485619, 1.0], [41.714978435, -87.655998622, 1.0], [41.978211897, -87.655746547, 1.0], [41.975559264, -87.654987667, 1.0], [41.802850483, -87.652664297, 1.0], [41.802477219, -87.652657244, 1.0], [41.766401059, -87.648086494, 1.0], [41.858281851, -87.646654964, 1.0], [41.750185415, -87.644029945, 1.0], [41.827159155, -87.641619819, 1.0], [41.926227907, -87.639139581, 1.0], [41.685119668, -87.638907587, 1.0], [41.780409069, -87.635057334, 1.0], [41.892383161, -87.634588313, 1.0], [41.879393185, -87.632992969, 1.0], [41.903129838, -87.631929153, 1.0], [41.903478069, -87.631433102, 1.0], [41.897021755, -87.629781141, 1.0], [41.699805673, -87.628716247, 1.0], [41.880251406, -87.626157171, 1.0], [41.885729338, -87.625780935, 1.0], [41.857196267, -87.625596317, 1.0], [41.880404956, -87.624356147, 1.0], [41.76508964, -87.623288534, 1.0], [41.772831904, -87.622942868, 1.0], [41.682581566, -87.617504356, 1.0], [41.783412793, -87.615701951, 1.0], [41.777950825, -87.615568537, 1.0], [41.807580274, -87.61547631, 1.0], [41.805124173, -87.615041585, 1.0], [41.7766178, -87.614802505, 1.0], [41.751164599, -87.612198632, 1.0], [41.69187607, -87.611711564, 1.0], [41.774327797, -87.610663438, 1.0], [41.696888796, -87.608909298, 1.0], [41.824058215, -87.606523648, 1.0], [41.74181305, -87.604967558, 1.0], [41.730949275, -87.604683641, 1.0], [41.800196824, -87.603936354, 1.0], [41.732105874, -87.603582467, 1.0], [41.750328686, -87.601521784, 1.0], [41.717810825, -87.595858138, 1.0], [41.803056534, -87.586453094, 1.0], [41.769261197, -87.584425842, 1.0], [41.74938132, -87.572285187, 1.0], [41.711241451, -87.56576559, 1.0], [41.709903512, -87.563906369, 1.0], [41.759040861, -87.562348408, 1.0], [41.733068435, -87.55133095, 1.0], [41.746053316, -87.549146964, 1.0], [41.654974814, -87.547146046, 1.0]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_bdde8d3a

# %% [markdown]
# <h1>FILTERING</h1>

# %%
filter1 = df[df['Primary Type'] == 'ASSAULT']

filter2 = filter1[filter1['Arrest'] == True]

filter3 = filter2[filter2['Year'] == 2025]

filter4 = filter3[filter3['Location Description'] == 'STREET']

# %% [markdown]
# <h1>INSIGHT3</h1>

# %% [markdown]
# <H4>Law Enforcement Efficiency</H4>
# <h4>Arrest presence suggests either higher police patrols in these zones or increased responsiveness in violent public disturbances.</h4>

# %%
map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8d85ed0f3f6707516a42f00812696e0c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8d85ed0f3f6707516a42f00812696e0c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8d85ed0f3f6707516a42f00812696e0c = L.map(
#                 &quot;map_8d85ed0f3f6707516a42f00812696e0c&quot;,
#                 {
#                     center: [41.8781, -87.6298],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_84dc3b3414efd8a5bfe55a7914905651 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_84dc3b3414efd8a5bfe55a7914905651.addTo(map_8d85ed0f3f6707516a42f00812696e0c);
#
#
#             var heat_map_4600c672c1c17eda740813a4799f6142 = L.heatLayer(
#                 [[41.909224529, -87.777791622, 1.0], [41.895995456, -87.772334331, 1.0], [41.893094286, -87.772231169, 1.0], [41.881183818, -87.76157228, 1.0], [41.909981092, -87.752659874, 1.0], [41.975292995, -87.750926925, 1.0], [41.875483068, -87.745085159, 1.0], [41.937749035, -87.740665125, 1.0], [41.935752015, -87.738162368, 1.0], [41.878743645, -87.736124908, 1.0], [41.883784731, -87.735578531, 1.0], [41.912465307, -87.732522476, 1.0], [41.854713363, -87.724844718, 1.0], [41.870735748, -87.724075964, 1.0], [41.866260112, -87.718457311, 1.0], [41.91134731, -87.717808027, 1.0], [41.959976534, -87.715553381, 1.0], [41.858303435, -87.715189395, 1.0], [41.841905622, -87.713504951, 1.0], [41.912997042, -87.711777872, 1.0], [41.872497397, -87.710742126, 1.0], [41.858568011, -87.710319284, 1.0], [41.840806317, -87.709155782, 1.0], [41.839955532, -87.706121788, 1.0], [41.783955089, -87.704493576, 1.0], [41.778962112, -87.703790763, 1.0], [41.795835835, -87.703621991, 1.0], [41.990447044, -87.698746362, 1.0], [41.776766148, -87.698210298, 1.0], [41.875902562, -87.69615018, 1.0], [41.910227448, -87.6961359, 1.0], [41.763935202, -87.690566076, 1.0], [41.822893602, -87.689118243, 1.0], [41.902999018, -87.688739745, 1.0], [41.934089387, -87.687941658, 1.0], [41.873882904, -87.686840358, 1.0], [41.838509873, -87.686433211, 1.0], [41.789485613, -87.683915798, 1.0], [42.015451197, -87.680481208, 1.0], [42.009269306, -87.675326876, 1.0], [42.00167049, -87.673863642, 1.0], [41.812222809, -87.666808738, 1.0], [41.694399654, -87.666481439, 1.0], [41.813312219, -87.666324236, 1.0], [42.019844934, -87.666216277, 1.0], [41.857112307, -87.666126249, 1.0], [41.794035506, -87.663814097, 1.0], [41.75322329, -87.663505427, 1.0], [41.857190995, -87.661735179, 1.0], [41.76312381, -87.661467128, 1.0], [41.869387636, -87.658659333, 1.0], [41.788449223, -87.658371945, 1.0], [41.860008714, -87.656485619, 1.0], [41.714978435, -87.655998622, 1.0], [41.978211897, -87.655746547, 1.0], [41.975559264, -87.654987667, 1.0], [41.802850483, -87.652664297, 1.0], [41.802477219, -87.652657244, 1.0], [41.766401059, -87.648086494, 1.0], [41.858281851, -87.646654964, 1.0], [41.750185415, -87.644029945, 1.0], [41.827159155, -87.641619819, 1.0], [41.926227907, -87.639139581, 1.0], [41.685119668, -87.638907587, 1.0], [41.780409069, -87.635057334, 1.0], [41.892383161, -87.634588313, 1.0], [41.879393185, -87.632992969, 1.0], [41.903129838, -87.631929153, 1.0], [41.903478069, -87.631433102, 1.0], [41.897021755, -87.629781141, 1.0], [41.699805673, -87.628716247, 1.0], [41.880251406, -87.626157171, 1.0], [41.885729338, -87.625780935, 1.0], [41.857196267, -87.625596317, 1.0], [41.880404956, -87.624356147, 1.0], [41.76508964, -87.623288534, 1.0], [41.772831904, -87.622942868, 1.0], [41.682581566, -87.617504356, 1.0], [41.783412793, -87.615701951, 1.0], [41.777950825, -87.615568537, 1.0], [41.807580274, -87.61547631, 1.0], [41.805124173, -87.615041585, 1.0], [41.7766178, -87.614802505, 1.0], [41.751164599, -87.612198632, 1.0], [41.69187607, -87.611711564, 1.0], [41.774327797, -87.610663438, 1.0], [41.696888796, -87.608909298, 1.0], [41.824058215, -87.606523648, 1.0], [41.74181305, -87.604967558, 1.0], [41.730949275, -87.604683641, 1.0], [41.800196824, -87.603936354, 1.0], [41.732105874, -87.603582467, 1.0], [41.750328686, -87.601521784, 1.0], [41.717810825, -87.595858138, 1.0], [41.803056534, -87.586453094, 1.0], [41.769261197, -87.584425842, 1.0], [41.74938132, -87.572285187, 1.0], [41.711241451, -87.56576559, 1.0], [41.709903512, -87.563906369, 1.0], [41.759040861, -87.562348408, 1.0], [41.733068435, -87.55133095, 1.0], [41.746053316, -87.549146964, 1.0], [41.654974814, -87.547146046, 1.0]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_4600c672

# %% [markdown]
# <h1>

# %%
# FILTERING
# 1) Select only assault incidents
filter1 = df[df['Primary Type'] == 'ASSAULT']

# 2) Keep only those that resulted in an arrest
filter2 = filter1[filter1['Arrest'] == True]

# 3) Keep only incidents from 2025
filter3 = filter2[filter2['Year'] == 2025]

# 4) Keep only street-level locations
filter4 = filter3[filter3['Location Description'] == 'STREET']

# GROUP & MAP
from folium import Map
from folium.plugins import HeatMap

# Aggregate by location
A_Assault = filter4.groupby(['Longitude', 'Latitude']) \
                  .size() \
                  .reset_index(name='Arrested Assault')

# Prepare heatmap data
heat_df = A_Assault[['Latitude', 'Longitude', 'Arrested Assault']].dropna().values.tolist()

# Create and display the map
map_ = Map(location=[41.8781, -87.6298], zoom_start=11)
HeatMap(heat_df).add_to(map_)
map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8d85ed0f3f6707516a42f00812696e0c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8d85ed0f3f6707516a42f00812696e0c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8d85ed0f3f6707516a42f00812696e0c = L.map(
#                 &quot;map_8d85ed0f3f6707516a42f00812696e0c&quot;,
#                 {
#                     center: [41.8781, -87.6298],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_84dc3b3414efd8a5bfe55a7914905651 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_84dc3b3414efd8a5bfe55a7914905651.addTo(map_8d85ed0f3f6707516a42f00812696e0c);
#
#
#             var heat_map_4600c672c1c17eda740813a4799f6142 = L.heatLayer(
#                 [[41.909224529, -87.777791622, 1.0], [41.895995456, -87.772334331, 1.0], [41.893094286, -87.772231169, 1.0], [41.881183818, -87.76157228, 1.0], [41.909981092, -87.752659874, 1.0], [41.975292995, -87.750926925, 1.0], [41.875483068, -87.745085159, 1.0], [41.937749035, -87.740665125, 1.0], [41.935752015, -87.738162368, 1.0], [41.878743645, -87.736124908, 1.0], [41.883784731, -87.735578531, 1.0], [41.912465307, -87.732522476, 1.0], [41.854713363, -87.724844718, 1.0], [41.870735748, -87.724075964, 1.0], [41.866260112, -87.718457311, 1.0], [41.91134731, -87.717808027, 1.0], [41.959976534, -87.715553381, 1.0], [41.858303435, -87.715189395, 1.0], [41.841905622, -87.713504951, 1.0], [41.912997042, -87.711777872, 1.0], [41.872497397, -87.710742126, 1.0], [41.858568011, -87.710319284, 1.0], [41.840806317, -87.709155782, 1.0], [41.839955532, -87.706121788, 1.0], [41.783955089, -87.704493576, 1.0], [41.778962112, -87.703790763, 1.0], [41.795835835, -87.703621991, 1.0], [41.990447044, -87.698746362, 1.0], [41.776766148, -87.698210298, 1.0], [41.875902562, -87.69615018, 1.0], [41.910227448, -87.6961359, 1.0], [41.763935202, -87.690566076, 1.0], [41.822893602, -87.689118243, 1.0], [41.902999018, -87.688739745, 1.0], [41.934089387, -87.687941658, 1.0], [41.873882904, -87.686840358, 1.0], [41.838509873, -87.686433211, 1.0], [41.789485613, -87.683915798, 1.0], [42.015451197, -87.680481208, 1.0], [42.009269306, -87.675326876, 1.0], [42.00167049, -87.673863642, 1.0], [41.812222809, -87.666808738, 1.0], [41.694399654, -87.666481439, 1.0], [41.813312219, -87.666324236, 1.0], [42.019844934, -87.666216277, 1.0], [41.857112307, -87.666126249, 1.0], [41.794035506, -87.663814097, 1.0], [41.75322329, -87.663505427, 1.0], [41.857190995, -87.661735179, 1.0], [41.76312381, -87.661467128, 1.0], [41.869387636, -87.658659333, 1.0], [41.788449223, -87.658371945, 1.0], [41.860008714, -87.656485619, 1.0], [41.714978435, -87.655998622, 1.0], [41.978211897, -87.655746547, 1.0], [41.975559264, -87.654987667, 1.0], [41.802850483, -87.652664297, 1.0], [41.802477219, -87.652657244, 1.0], [41.766401059, -87.648086494, 1.0], [41.858281851, -87.646654964, 1.0], [41.750185415, -87.644029945, 1.0], [41.827159155, -87.641619819, 1.0], [41.926227907, -87.639139581, 1.0], [41.685119668, -87.638907587, 1.0], [41.780409069, -87.635057334, 1.0], [41.892383161, -87.634588313, 1.0], [41.879393185, -87.632992969, 1.0], [41.903129838, -87.631929153, 1.0], [41.903478069, -87.631433102, 1.0], [41.897021755, -87.629781141, 1.0], [41.699805673, -87.628716247, 1.0], [41.880251406, -87.626157171, 1.0], [41.885729338, -87.625780935, 1.0], [41.857196267, -87.625596317, 1.0], [41.880404956, -87.624356147, 1.0], [41.76508964, -87.623288534, 1.0], [41.772831904, -87.622942868, 1.0], [41.682581566, -87.617504356, 1.0], [41.783412793, -87.615701951, 1.0], [41.777950825, -87.615568537, 1.0], [41.807580274, -87.61547631, 1.0], [41.805124173, -87.615041585, 1.0], [41.7766178, -87.614802505, 1.0], [41.751164599, -87.612198632, 1.0], [41.69187607, -87.611711564, 1.0], [41.774327797, -87.610663438, 1.0], [41.696888796, -87.608909298, 1.0], [41.824058215, -87.606523648, 1.0], [41.74181305, -87.604967558, 1.0], [41.730949275, -87.604683641, 1.0], [41.800196824, -87.603936354, 1.0], [41.732105874, -87.603582467, 1.0], [41.750328686, -87.601521784, 1.0], [41.717810825, -87.595858138, 1.0], [41.803056534, -87.586453094, 1.0], [41.769261197, -87.584425842, 1.0], [41.74938132, -87.572285187, 1.0], [41.711241451, -87.56576559, 1.0], [41.709903512, -87.563906369, 1.0], [41.759040861, -87.562348408, 1.0], [41.733068435, -87.55133095, 1.0], [41.746053316, -87.549146964, 1.0], [41.654974814, -87.547146046, 1.0]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_4600c672

# %% [markdown]
# <H1>INSIGHT4</H1>

# %% [markdown]
# <H4>Recurring High-Risk Zones</H4>
# <H4>Areas like South Michigan Avenue repeatedly emerge in both data and news, affirming them as chronic danger zones.</H4>

# %%
map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8d85ed0f3f6707516a42f00812696e0c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8d85ed0f3f6707516a42f00812696e0c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8d85ed0f3f6707516a42f00812696e0c = L.map(
#                 &quot;map_8d85ed0f3f6707516a42f00812696e0c&quot;,
#                 {
#                     center: [41.8781, -87.6298],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_84dc3b3414efd8a5bfe55a7914905651 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_84dc3b3414efd8a5bfe55a7914905651.addTo(map_8d85ed0f3f6707516a42f00812696e0c);
#
#
#             var heat_map_4600c672c1c17eda740813a4799f6142 = L.heatLayer(
#                 [[41.909224529, -87.777791622, 1.0], [41.895995456, -87.772334331, 1.0], [41.893094286, -87.772231169, 1.0], [41.881183818, -87.76157228, 1.0], [41.909981092, -87.752659874, 1.0], [41.975292995, -87.750926925, 1.0], [41.875483068, -87.745085159, 1.0], [41.937749035, -87.740665125, 1.0], [41.935752015, -87.738162368, 1.0], [41.878743645, -87.736124908, 1.0], [41.883784731, -87.735578531, 1.0], [41.912465307, -87.732522476, 1.0], [41.854713363, -87.724844718, 1.0], [41.870735748, -87.724075964, 1.0], [41.866260112, -87.718457311, 1.0], [41.91134731, -87.717808027, 1.0], [41.959976534, -87.715553381, 1.0], [41.858303435, -87.715189395, 1.0], [41.841905622, -87.713504951, 1.0], [41.912997042, -87.711777872, 1.0], [41.872497397, -87.710742126, 1.0], [41.858568011, -87.710319284, 1.0], [41.840806317, -87.709155782, 1.0], [41.839955532, -87.706121788, 1.0], [41.783955089, -87.704493576, 1.0], [41.778962112, -87.703790763, 1.0], [41.795835835, -87.703621991, 1.0], [41.990447044, -87.698746362, 1.0], [41.776766148, -87.698210298, 1.0], [41.875902562, -87.69615018, 1.0], [41.910227448, -87.6961359, 1.0], [41.763935202, -87.690566076, 1.0], [41.822893602, -87.689118243, 1.0], [41.902999018, -87.688739745, 1.0], [41.934089387, -87.687941658, 1.0], [41.873882904, -87.686840358, 1.0], [41.838509873, -87.686433211, 1.0], [41.789485613, -87.683915798, 1.0], [42.015451197, -87.680481208, 1.0], [42.009269306, -87.675326876, 1.0], [42.00167049, -87.673863642, 1.0], [41.812222809, -87.666808738, 1.0], [41.694399654, -87.666481439, 1.0], [41.813312219, -87.666324236, 1.0], [42.019844934, -87.666216277, 1.0], [41.857112307, -87.666126249, 1.0], [41.794035506, -87.663814097, 1.0], [41.75322329, -87.663505427, 1.0], [41.857190995, -87.661735179, 1.0], [41.76312381, -87.661467128, 1.0], [41.869387636, -87.658659333, 1.0], [41.788449223, -87.658371945, 1.0], [41.860008714, -87.656485619, 1.0], [41.714978435, -87.655998622, 1.0], [41.978211897, -87.655746547, 1.0], [41.975559264, -87.654987667, 1.0], [41.802850483, -87.652664297, 1.0], [41.802477219, -87.652657244, 1.0], [41.766401059, -87.648086494, 1.0], [41.858281851, -87.646654964, 1.0], [41.750185415, -87.644029945, 1.0], [41.827159155, -87.641619819, 1.0], [41.926227907, -87.639139581, 1.0], [41.685119668, -87.638907587, 1.0], [41.780409069, -87.635057334, 1.0], [41.892383161, -87.634588313, 1.0], [41.879393185, -87.632992969, 1.0], [41.903129838, -87.631929153, 1.0], [41.903478069, -87.631433102, 1.0], [41.897021755, -87.629781141, 1.0], [41.699805673, -87.628716247, 1.0], [41.880251406, -87.626157171, 1.0], [41.885729338, -87.625780935, 1.0], [41.857196267, -87.625596317, 1.0], [41.880404956, -87.624356147, 1.0], [41.76508964, -87.623288534, 1.0], [41.772831904, -87.622942868, 1.0], [41.682581566, -87.617504356, 1.0], [41.783412793, -87.615701951, 1.0], [41.777950825, -87.615568537, 1.0], [41.807580274, -87.61547631, 1.0], [41.805124173, -87.615041585, 1.0], [41.7766178, -87.614802505, 1.0], [41.751164599, -87.612198632, 1.0], [41.69187607, -87.611711564, 1.0], [41.774327797, -87.610663438, 1.0], [41.696888796, -87.608909298, 1.0], [41.824058215, -87.606523648, 1.0], [41.74181305, -87.604967558, 1.0], [41.730949275, -87.604683641, 1.0], [41.800196824, -87.603936354, 1.0], [41.732105874, -87.603582467, 1.0], [41.750328686, -87.601521784, 1.0], [41.717810825, -87.595858138, 1.0], [41.803056534, -87.586453094, 1.0], [41.769261197, -87.584425842, 1.0], [41.74938132, -87.572285187, 1.0], [41.711241451, -87.56576559, 1.0], [41.709903512, -87.563906369, 1.0], [41.759040861, -87.562348408, 1.0], [41.733068435, -87.55133095, 1.0], [41.746053316, -87.549146964, 1.0], [41.654974814, -87.547146046, 1.0]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_4600c672

# %% [markdown]
# <H1>FILTERING</H1>

# %%
# FILTERING
# 1) Select only assault incidents
filter1 = df[df['Primary Type'] == 'ASSAULT']

# 2) Keep only those that resulted in an arrest
filter2 = filter1[filter1['Arrest'] == True]

# 3) Keep only incidents from 2025
filter3 = filter2[filter2['Year'] == 2025]

# 4) Keep only street‐level locations
filter4 = filter3[filter3['Location Description'] == 'STREET']

# GROUP & AGGREGATE for heatmap
A_Assault = (
    filter4
    .groupby(['Longitude', 'Latitude'])
    .size()
    .reset_index(name='Arrested Assault')
)

# CREATE AND DISPLAY HEATMAP
import folium
from folium.plugins import HeatMap

heat_df = A_Assault[['Latitude', 'Longitude', 'Arrested Assault']].dropna().values.tolist()
map_ = folium.Map(location=[41.8781, -87.6298], zoom_start=11)  # Center on Chicago
HeatMap(heat_df).add_to(map_)
map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d56e3b1cdb83218eea4d663136bbc6c5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d56e3b1cdb83218eea4d663136bbc6c5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d56e3b1cdb83218eea4d663136bbc6c5 = L.map(
#                 &quot;map_d56e3b1cdb83218eea4d663136bbc6c5&quot;,
#                 {
#                     center: [41.8781, -87.6298],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f2c1c4df148731805583d956f7d7e00c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f2c1c4df148731805583d956f7d7e00c.addTo(map_d56e3b1cdb83218eea4d663136bbc6c5);
#
#
#             var heat_map_8a5320a75c0256c5ccdc5c844c4475eb = L.heatLayer(
#                 [[41.909224529, -87.777791622, 1.0], [41.895995456, -87.772334331, 1.0], [41.893094286, -87.772231169, 1.0], [41.881183818, -87.76157228, 1.0], [41.909981092, -87.752659874, 1.0], [41.975292995, -87.750926925, 1.0], [41.875483068, -87.745085159, 1.0], [41.937749035, -87.740665125, 1.0], [41.935752015, -87.738162368, 1.0], [41.878743645, -87.736124908, 1.0], [41.883784731, -87.735578531, 1.0], [41.912465307, -87.732522476, 1.0], [41.854713363, -87.724844718, 1.0], [41.870735748, -87.724075964, 1.0], [41.866260112, -87.718457311, 1.0], [41.91134731, -87.717808027, 1.0], [41.959976534, -87.715553381, 1.0], [41.858303435, -87.715189395, 1.0], [41.841905622, -87.713504951, 1.0], [41.912997042, -87.711777872, 1.0], [41.872497397, -87.710742126, 1.0], [41.858568011, -87.710319284, 1.0], [41.840806317, -87.709155782, 1.0], [41.839955532, -87.706121788, 1.0], [41.783955089, -87.704493576, 1.0], [41.778962112, -87.703790763, 1.0], [41.795835835, -87.703621991, 1.0], [41.990447044, -87.698746362, 1.0], [41.776766148, -87.698210298, 1.0], [41.875902562, -87.69615018, 1.0], [41.910227448, -87.6961359, 1.0], [41.763935202, -87.690566076, 1.0], [41.822893602, -87.689118243, 1.0], [41.902999018, -87.688739745, 1.0], [41.934089387, -87.687941658, 1.0], [41.873882904, -87.686840358, 1.0], [41.838509873, -87.686433211, 1.0], [41.789485613, -87.683915798, 1.0], [42.015451197, -87.680481208, 1.0], [42.009269306, -87.675326876, 1.0], [42.00167049, -87.673863642, 1.0], [41.812222809, -87.666808738, 1.0], [41.694399654, -87.666481439, 1.0], [41.813312219, -87.666324236, 1.0], [42.019844934, -87.666216277, 1.0], [41.857112307, -87.666126249, 1.0], [41.794035506, -87.663814097, 1.0], [41.75322329, -87.663505427, 1.0], [41.857190995, -87.661735179, 1.0], [41.76312381, -87.661467128, 1.0], [41.869387636, -87.658659333, 1.0], [41.788449223, -87.658371945, 1.0], [41.860008714, -87.656485619, 1.0], [41.714978435, -87.655998622, 1.0], [41.978211897, -87.655746547, 1.0], [41.975559264, -87.654987667, 1.0], [41.802850483, -87.652664297, 1.0], [41.802477219, -87.652657244, 1.0], [41.766401059, -87.648086494, 1.0], [41.858281851, -87.646654964, 1.0], [41.750185415, -87.644029945, 1.0], [41.827159155, -87.641619819, 1.0], [41.926227907, -87.639139581, 1.0], [41.685119668, -87.638907587, 1.0], [41.780409069, -87.635057334, 1.0], [41.892383161, -87.634588313, 1.0], [41.879393185, -87.632992969, 1.0], [41.903129838, -87.631929153, 1.0], [41.903478069, -87.631433102, 1.0], [41.897021755, -87.629781141, 1.0], [41.699805673, -87.628716247, 1.0], [41.880251406, -87.626157171, 1.0], [41.885729338, -87.625780935, 1.0], [41.857196267, -87.625596317, 1.0], [41.880404956, -87.624356147, 1.0], [41.76508964, -87.623288534, 1.0], [41.772831904, -87.622942868, 1.0], [41.682581566, -87.617504356, 1.0], [41.783412793, -87.615701951, 1.0], [41.777950825, -87.615568537, 1.0], [41.807580274, -87.61547631, 1.0], [41.805124173, -87.615041585, 1.0], [41.7766178, -87.614802505, 1.0], [41.751164599, -87.612198632, 1.0], [41.69187607, -87.611711564, 1.0], [41.774327797, -87.610663438, 1.0], [41.696888796, -87.608909298, 1.0], [41.824058215, -87.606523648, 1.0], [41.74181305, -87.604967558, 1.0], [41.730949275, -87.604683641, 1.0], [41.800196824, -87.603936354, 1.0], [41.732105874, -87.603582467, 1.0], [41.750328686, -87.601521784, 1.0], [41.717810825, -87.595858138, 1.0], [41.803056534, -87.586453094, 1.0], [41.769261197, -87.584425842, 1.0], [41.74938132, -87.572285187, 1.0], [41.711241451, -87.56576559, 1.0], [41.709903512, -87.563906369, 1.0], [41.759040861, -87.562348408, 1.0], [41.733068435, -87.55133095, 1.0], [41.746053316, -87.549146964, 1.0], [41.654974814, -87.547146046, 1.0]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_8a5320a7

# %% [markdown]
# <H1>INSIGHT5</H1>

# %% [markdown]
# <H4>Public Safety Strategy</H4>
# <H4>This data-backed heatmap can help city planners and law enforcement focus patrols and violence prevention efforts where they’re most needed.</H4>

# %%
map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d56e3b1cdb83218eea4d663136bbc6c5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d56e3b1cdb83218eea4d663136bbc6c5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d56e3b1cdb83218eea4d663136bbc6c5 = L.map(
#                 &quot;map_d56e3b1cdb83218eea4d663136bbc6c5&quot;,
#                 {
#                     center: [41.8781, -87.6298],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f2c1c4df148731805583d956f7d7e00c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f2c1c4df148731805583d956f7d7e00c.addTo(map_d56e3b1cdb83218eea4d663136bbc6c5);
#
#
#             var heat_map_8a5320a75c0256c5ccdc5c844c4475eb = L.heatLayer(
#                 [[41.909224529, -87.777791622, 1.0], [41.895995456, -87.772334331, 1.0], [41.893094286, -87.772231169, 1.0], [41.881183818, -87.76157228, 1.0], [41.909981092, -87.752659874, 1.0], [41.975292995, -87.750926925, 1.0], [41.875483068, -87.745085159, 1.0], [41.937749035, -87.740665125, 1.0], [41.935752015, -87.738162368, 1.0], [41.878743645, -87.736124908, 1.0], [41.883784731, -87.735578531, 1.0], [41.912465307, -87.732522476, 1.0], [41.854713363, -87.724844718, 1.0], [41.870735748, -87.724075964, 1.0], [41.866260112, -87.718457311, 1.0], [41.91134731, -87.717808027, 1.0], [41.959976534, -87.715553381, 1.0], [41.858303435, -87.715189395, 1.0], [41.841905622, -87.713504951, 1.0], [41.912997042, -87.711777872, 1.0], [41.872497397, -87.710742126, 1.0], [41.858568011, -87.710319284, 1.0], [41.840806317, -87.709155782, 1.0], [41.839955532, -87.706121788, 1.0], [41.783955089, -87.704493576, 1.0], [41.778962112, -87.703790763, 1.0], [41.795835835, -87.703621991, 1.0], [41.990447044, -87.698746362, 1.0], [41.776766148, -87.698210298, 1.0], [41.875902562, -87.69615018, 1.0], [41.910227448, -87.6961359, 1.0], [41.763935202, -87.690566076, 1.0], [41.822893602, -87.689118243, 1.0], [41.902999018, -87.688739745, 1.0], [41.934089387, -87.687941658, 1.0], [41.873882904, -87.686840358, 1.0], [41.838509873, -87.686433211, 1.0], [41.789485613, -87.683915798, 1.0], [42.015451197, -87.680481208, 1.0], [42.009269306, -87.675326876, 1.0], [42.00167049, -87.673863642, 1.0], [41.812222809, -87.666808738, 1.0], [41.694399654, -87.666481439, 1.0], [41.813312219, -87.666324236, 1.0], [42.019844934, -87.666216277, 1.0], [41.857112307, -87.666126249, 1.0], [41.794035506, -87.663814097, 1.0], [41.75322329, -87.663505427, 1.0], [41.857190995, -87.661735179, 1.0], [41.76312381, -87.661467128, 1.0], [41.869387636, -87.658659333, 1.0], [41.788449223, -87.658371945, 1.0], [41.860008714, -87.656485619, 1.0], [41.714978435, -87.655998622, 1.0], [41.978211897, -87.655746547, 1.0], [41.975559264, -87.654987667, 1.0], [41.802850483, -87.652664297, 1.0], [41.802477219, -87.652657244, 1.0], [41.766401059, -87.648086494, 1.0], [41.858281851, -87.646654964, 1.0], [41.750185415, -87.644029945, 1.0], [41.827159155, -87.641619819, 1.0], [41.926227907, -87.639139581, 1.0], [41.685119668, -87.638907587, 1.0], [41.780409069, -87.635057334, 1.0], [41.892383161, -87.634588313, 1.0], [41.879393185, -87.632992969, 1.0], [41.903129838, -87.631929153, 1.0], [41.903478069, -87.631433102, 1.0], [41.897021755, -87.629781141, 1.0], [41.699805673, -87.628716247, 1.0], [41.880251406, -87.626157171, 1.0], [41.885729338, -87.625780935, 1.0], [41.857196267, -87.625596317, 1.0], [41.880404956, -87.624356147, 1.0], [41.76508964, -87.623288534, 1.0], [41.772831904, -87.622942868, 1.0], [41.682581566, -87.617504356, 1.0], [41.783412793, -87.615701951, 1.0], [41.777950825, -87.615568537, 1.0], [41.807580274, -87.61547631, 1.0], [41.805124173, -87.615041585, 1.0], [41.7766178, -87.614802505, 1.0], [41.751164599, -87.612198632, 1.0], [41.69187607, -87.611711564, 1.0], [41.774327797, -87.610663438, 1.0], [41.696888796, -87.608909298, 1.0], [41.824058215, -87.606523648, 1.0], [41.74181305, -87.604967558, 1.0], [41.730949275, -87.604683641, 1.0], [41.800196824, -87.603936354, 1.0], [41.732105874, -87.603582467, 1.0], [41.750328686, -87.601521784, 1.0], [41.717810825, -87.595858138, 1.0], [41.803056534, -87.586453094, 1.0], [41.769261197, -87.584425842, 1.0], [41.74938132, -87.572285187, 1.0], [41.711241451, -87.56576559, 1.0], [41.709903512, -87.563906369, 1.0], [41.759040861, -87.562348408, 1.0], [41.733068435, -87.55133095, 1.0], [41.746053316, -87.549146964, 1.0], [41.654974814, -87.547146046, 1.0]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_8a5320a7

# %% [markdown]
# <H1>FILTERING</H1>

# %%
# FILTERING for Insight 5: Public Safety Strategy
# 1) Select only assault incidents
filter1 = df[df['Primary Type'] == 'ASSAULT']

# 2) Keep only those that resulted in an arrest
filter2 = filter1[filter1['Arrest'] == True]

# 3) Keep only incidents from 2025
filter3 = filter2[filter2['Year'] == 2025]

# 4) Keep only street‐level locations
filter4 = filter3[filter3['Location Description'] == 'STREET']

# GROUP & AGGREGATE for heatmap
A_Assault = (
    filter4
    .groupby(['Longitude', 'Latitude'])
    .size()
    .reset_index(name='Arrested Assault')
)

# CREATE AND DISPLAY HEATMAP
import folium
from folium.plugins import HeatMap

heat_df = A_Assault[['Latitude', 'Longitude', 'Arrested Assault']].dropna().values.tolist()
map_ = folium.Map(location=[41.8781, -87.6298], zoom_start=11)  # Center on Chicago
HeatMap(heat_df).add_to(map_)
map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_58071d652a9a596a8142e7c00acfb22d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_58071d652a9a596a8142e7c00acfb22d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_58071d652a9a596a8142e7c00acfb22d = L.map(
#                 &quot;map_58071d652a9a596a8142e7c00acfb22d&quot;,
#                 {
#                     center: [41.8781, -87.6298],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b8b1972cc55a2cca80066c0c211e49ce = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b8b1972cc55a2cca80066c0c211e49ce.addTo(map_58071d652a9a596a8142e7c00acfb22d);
#
#
#             var heat_map_9215b4afe09ea3f937905ac28cb6c7ef = L.heatLayer(
#                 [[41.909224529, -87.777791622, 1.0], [41.895995456, -87.772334331, 1.0], [41.893094286, -87.772231169, 1.0], [41.881183818, -87.76157228, 1.0], [41.909981092, -87.752659874, 1.0], [41.975292995, -87.750926925, 1.0], [41.875483068, -87.745085159, 1.0], [41.937749035, -87.740665125, 1.0], [41.935752015, -87.738162368, 1.0], [41.878743645, -87.736124908, 1.0], [41.883784731, -87.735578531, 1.0], [41.912465307, -87.732522476, 1.0], [41.854713363, -87.724844718, 1.0], [41.870735748, -87.724075964, 1.0], [41.866260112, -87.718457311, 1.0], [41.91134731, -87.717808027, 1.0], [41.959976534, -87.715553381, 1.0], [41.858303435, -87.715189395, 1.0], [41.841905622, -87.713504951, 1.0], [41.912997042, -87.711777872, 1.0], [41.872497397, -87.710742126, 1.0], [41.858568011, -87.710319284, 1.0], [41.840806317, -87.709155782, 1.0], [41.839955532, -87.706121788, 1.0], [41.783955089, -87.704493576, 1.0], [41.778962112, -87.703790763, 1.0], [41.795835